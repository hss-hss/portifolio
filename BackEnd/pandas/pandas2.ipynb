# %%
import pandas as pd

vendas_df = pd.read_csv('Vendas.csv',sep = ';')
vendas_df["Data da Venda"]
# Out:
# 0         01/01/2017
# 1         01/01/2017
# 2         01/01/2017
# 3         01/01/2017
# 4         01/01/2017
#              ...
# 980637    31/12/2017
# 980638    31/12/2017
# 980639    31/12/2017
# 980640    31/12/2017
# 980641    31/12/2017
# Name: Data da Venda, Length: 980642, dtype: str

# %%
import pandas as pd

vendas_df = pd.read_csv('Vendas.csv',sep = ';')
vendas_df["ID Cliente"]
# Out:
# 0          6825
# 1         18469
# 2         19730
# 3         29326
# 4         22617
#           ...
# 980637    10353
# 980638    31750
# 980639    12003
# 980640    25550
# 980641    28707
# Name: ID Cliente, Length: 980642, dtype: int64

# %%
import pandas as pd

vendas_df = pd.read_csv('Vendas.csv',sep = ';')
vendas_df
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
vendas_df = pd.read_csv('Vendas.csv',sep = ';')
vendas_df[2:3]
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 2                3    01/01/2017    01/01/2017         0      294        1444
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida
# 2            5       19730                  13                     1

# %%
import pandas as pd

vendas_df = pd.read_csv('Vendas.csv',sep = ';')

def_vendas_clientes = vendas_df[['ID Cliente', 'Quantidade Vendida']]
def_vendas_clientes
# Out:
#         ID Cliente  Quantidade Vendida
# 0             6825                   9
# 1            18469                   9
# 2            19730                  13
# 3            29326                   6
# 4            22617                   4
# ...            ...                 ...
# 980637       10353                 120
# 980638       31750                 120
# 980639       12003                  80
# 980640       25550                  39
# 980641       28707                  80
#
# [980642 rows x 2 columns]

# %%
import pandas as pd

vendas_df = pd.read_csv('Vendas.csv',sep = ';')
vendas_df["ID Cliente"][100]
# Out:
# np.int64(15871)

# %%
import pandas as pd

vendas_df = pd.read_csv('Vendas.csv',sep = ';')
vendas_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 980642 entries, 0 to 980641
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Numero da Venda       980642 non-null  int64
#  1   Data da Venda         980642 non-null  str
#  2   Data do Envio         980642 non-null  str
#  3   ID Canal              980642 non-null  int64
#  4   ID Loja               980642 non-null  int64
#  5   ID Produto            980642 non-null  int64
#  6   ID Promocao           980642 non-null  int64
#  7   ID Cliente            980642 non-null  int64
#  8   Quantidade Vendida    980642 non-null  int64
#  9   Quantidade Devolvida  980642 non-null  int64
# dtypes: int64(8), str(2)
# memory usage: 74.8 MB

# %%
import pandas as pd

vendas_df = pd.read_csv(r'Vendas.csv',sep = ';')
produtos_df = pd.read_csv(r'CadastroProdutos.csv', sep = ';')
lojas_df = pd.read_csv(r'Lojas.csv', sep = ';')
clientes_df = pd.read_csv(r'Clientes.csv', sep = ';')

display(vendas_df)
display(produtos_df)
display(lojas_df)
display(clientes_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
vendas_df = vendas_df.merge(produtos_df, on="ID Produto")
vendas_df = vendas_df.merge(lojas_df, on="ID Loja")
vendas_df = vendas_df.merge(clientes_df, on= "ID Cliente")

display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
colunasParaRemover = ['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10']
clientes_df = clientes_df.drop(columns=[coluna for coluna in colunasParaRemover if coluna in clientes_df.columns])
display(clientes_df)
# Out:
#        ID Cliente Primeiro Nome     Sobrenome                         E-mail  \
# 0               1        Garnet    Lanfranchi    glanfranchi0@mayoclinic.com
# 1               2       Lurette     Roseblade      lroseblade1@bigcartel.com
# 2               3       Glenden     Ishchenko      gishchenko2@moonfruit.com
# 3               4         Baron  Jedrzejewsky    bjedrzejewsky3@e-recht24.de
# 4               5        Sheree      Bredbury       sbredbury4@sitemeter.com
# ...           ...           ...           ...                            ...
# 39499       39500        Brandy      Malhotra    brandy0@adventure-works.com
# 39500       39501        Alicia          Raje   alicia12@adventure-works.com
# 39501       39502        Connie           Rai    connie4@adventure-works.com
# 39502       39503         Shawn          Raji    shawn23@adventure-works.com
# 39503       39504       Lindsey        Sharma  lindsey10@adventure-works.com
#
# ...

# %%
vendas_df = vendas_df.rename(columns={'E-mail':'E-mail Do Cliente'})
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
frequencia_clientes= vendas_df['E-mail Do Cliente'].value_counts()
display(frequencia_clientes)
frequencia_clientes.plot()
# Out:
# E-mail Do Cliente
# karen33@adventure-works.com      77
# chloe77@adventure-works.com      74
# julia43@adventure-works.com      69
# destiny66@adventure-works.com    68
# karen16@adventure-works.com      68
#                                  ..
# ckilfoyle88@yahoo.co.jp           1
# pmcgaheylk@nbcnews.com            1
# osaffleev@hao123.com              1
# mtrimmill2d@abc.net.au            1
# clifford8@adventure-works.com     1
# Name: count, Length: 38907, dtype: int64
# <Axes: xlabel='E-mail Do Cliente'>

# %%
vendas_lojas = vendas_df.groupby('Nome da Loja').sum()
vendas_lojas = vendas_lojas[['Quantidade Vendida', 'Quantidade Devolvida']]
display(vendas_lojas)
# Out:
#                           Quantidade Vendida  Quantidade Devolvida
# Nome da Loja
# Loja Contoso Albany                    26353                   298
# Loja Contoso Alexandria                26247                   326
# Loja Contoso Amsterdam                 28294                   401
# Loja Contoso Anchorage                 27451                   361
# Loja Contoso Annapolis                 26065                   300
# ...                                      ...                   ...
# Loja Contoso Yokohama                  28023                   367
# Loja Contoso York                      27164                   365
# Loja Contoso koln No.1                 29046                   356
# Loja Contoso koln No.2                 29650                   417
# Loja Contoso obamberg                  29336                   378
#
# [306 rows x 2 columns]

# %%
vendas_lojas = vendas_df.groupby('Nome da Loja').sum()
vendas_lojas = vendas_lojas[['Quantidade Vendida']]
display(vendas_lojas)
# Out:
#                           Quantidade Vendida
# Nome da Loja
# Loja Contoso Albany                    26353
# Loja Contoso Alexandria                26247
# Loja Contoso Amsterdam                 28294
# Loja Contoso Anchorage                 27451
# Loja Contoso Annapolis                 26065
# ...                                      ...
# Loja Contoso Yokohama                  28023
# Loja Contoso York                      27164
# Loja Contoso koln No.1                 29046
# Loja Contoso koln No.2                 29650
# Loja Contoso obamberg                  29336
#
# [306 rows x 1 columns]

# %%
vendas_lojas = vendas_df.sort_values('Quantidade Vendida', ascending=False)
display(vendas_lojas)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 850074           850075    12/11/2017    12/11/2017         0      200
# 897464           897465    30/11/2017    30/11/2017         0      200
# 891965           891966    28/11/2017    28/11/2017         0      200
# 477705           477706    25/06/2017    25/06/2017         0      307
# 868544           868545    19/11/2017    26/11/2017         7      200
# ...                 ...           ...           ...       ...      ...
# 894500           894501    29/11/2017    30/11/2017         1      250
# 894501           894502    29/11/2017    29/11/2017         0      204
# 894502           894503    29/11/2017    29/11/2017         0      205
# 894503           894504    29/11/2017    01/12/2017         2      246
# 894504           894505    29/11/2017    29/11/2017         0      303
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
vendas_lojas = vendas_lojas[['Quantidade Vendida']]
display(vendas_lojas)
vendas_lojas[:5].plot(figsize=(15,5), kind='bar')
# Out:
#         Quantidade Vendida
# 850074                1200
# 897464                 960
# 891965                 960
# 477705                 840
# 868544                 720
# ...                    ...
# 894500                   4
# 894501                   4
# 894502                   4
# 894503                   4
# 894504                   4
#
# [980642 rows x 1 columns]
# <Axes: >

# %%
qtde_vendida = vendas_df['Quantidade Vendida'].sum()
qtde_devolvida = vendas_df['Quantidade Devolvida'].sum()
print('{:.2%}'.format(qtde_devolvida/qtde_vendida))
# Out:
# 1.17%

# %%
vendas_lojacontoso = vendas_df[vendas_df['ID Loja'] == 306]
display(vendas_lojacontoso)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 98                   99    01/01/2017    03/01/2017         2      306
# 165                 166    01/01/2017    02/01/2017         1      306
# 166                 167    01/01/2017    05/01/2017         4      306
# 186                 187    01/01/2017    06/01/2017         5      306
# 198                 199    01/01/2017    03/01/2017         2      306
# ...                 ...           ...           ...       ...      ...
# 980579           980580    31/12/2017    06/01/2018         6      306
# 980580           980581    31/12/2017    01/01/2018         1      306
# 980581           980582    31/12/2017    31/12/2017         0      306
# 980582           980583    31/12/2017    03/01/2018         3      306
# 980632           980633    31/12/2017    31/12/2017         0      306
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
loja306 = vendas_df['ID Loja'] == 306
vendas_lojacontoso = vendas_df[loja306]
display(vendas_lojacontoso)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 98                   99    01/01/2017    03/01/2017         2      306
# 165                 166    01/01/2017    02/01/2017         1      306
# 166                 167    01/01/2017    05/01/2017         4      306
# 186                 187    01/01/2017    06/01/2017         5      306
# 198                 199    01/01/2017    03/01/2017         2      306
# ...                 ...           ...           ...       ...      ...
# 980579           980580    31/12/2017    06/01/2018         6      306
# 980580           980581    31/12/2017    01/01/2018         1      306
# 980581           980582    31/12/2017    31/12/2017         0      306
# 980582           980583    31/12/2017    03/01/2018         3      306
# 980632           980633    31/12/2017    31/12/2017         0      306
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
df_loja306semdev = vendas_df[(vendas_df['ID Loja'] == 306) & (vendas_df['Quantidade Devolvida'] ==0)]
display(df_loja306semdev)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 98                   99    01/01/2017    03/01/2017         2      306
# 165                 166    01/01/2017    02/01/2017         1      306
# 166                 167    01/01/2017    05/01/2017         4      306
# 186                 187    01/01/2017    06/01/2017         5      306
# 198                 199    01/01/2017    03/01/2017         2      306
# ...                 ...           ...           ...       ...      ...
# 980579           980580    31/12/2017    06/01/2018         6      306
# 980580           980581    31/12/2017    01/01/2018         1      306
# 980581           980582    31/12/2017    31/12/2017         0      306
# 980582           980583    31/12/2017    03/01/2018         3      306
# 980632           980633    31/12/2017    31/12/2017         0      306
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
vendas_df['Data da Venda'] = pd.to_datetime(vendas_df['Data da Venda'], format='%d/%m/%Y')
vendas_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 980642 entries, 0 to 980641
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Numero da Venda           980642 non-null  int64
#  1   Data da Venda             980642 non-null  datetime64[us]
#  2   Data do Envio             980642 non-null  str
#  3   ID Canal                  980642 non-null  int64
#  4   ID Loja                   980642 non-null  int64
#  5   ID Produto                980642 non-null  int64
#  6   ID Promocao               980642 non-null  int64
#  7   ID Cliente                980642 non-null  int64
#  8   Quantidade Vendida        980642 non-null  int64
#  9   Quantidade Devolvida      980642 non-null  int64
#  10  Nome da Marca             980642 non-null  str
#  11  Tipo                      980642 non-null  str
#  12  Custo Unitario            980642 non-null  str
# ...

# %%
vendas_df['Data da Venda'] = pd.to_datetime(vendas_df['Data da Venda'], format='%d/%m/%Y')
vendas_df['Ano da Venda'] = vendas_df['Data da Venda'].dt.year
vendas_df['Mes da Venda'] = vendas_df['Data da Venda'].dt.month
vendas_df['Dia da Venda'] = vendas_df['Data da Venda'].dt.day

display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    2017-01-01    02/01/2017         1       86
# 1                     2    2017-01-01    06/01/2017         5      308
# 2                     3    2017-01-01    01/01/2017         0      294
# 3                     4    2017-01-01    01/01/2017         0      251
# 4                     5    2017-01-01    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    2017-12-31    31/12/2017         0      194
# 980638           980639    2017-12-31    06/01/2018         6       32
# 980639           980640    2017-12-31    03/01/2018         3      210
# 980640           980641    2017-12-31    31/12/2017         0       53
# 980641           980642    2017-12-31    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...
