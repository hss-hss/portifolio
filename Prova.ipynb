# %%
import matplotlib.pyplot as plt

labels = ['A','B','C','D']
sizes = [15,30,45,10]

plt.pie(sizes,labels=labels,autopct='%.1f')
plt.show()

# %%
categories = ['Jan','Feb','Mar','Apr']
values = [10,20,15,25]

plt.bar(categories,values)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]

plt.plot(x,y)
plt.show()

# %%
categories = ['Produto A','Produto B','Produto C']
values = [30,40,50]


plt.barh(categories,values)
plt.show()

# %%
labels =['Ferias','Trabalho','Lazer']
sizes = [40,30,30]

plt.pie(sizes,labels=labels,autopct='%.1f')
plt.show()

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]

plt.plot(x,y)
plt.show()

# %%
months = ['Jan','Feb','Mar','Apr']
sales = [100,150,120,180]

plt.bar(months,sales)
plt.show()

# %%
labels = ['Carro','Bicicleta','Ônibus','A pé']
sizes = [40,30,20,10]

plt.pie(sizes,labels=labels,autopct='%0.1f')
plt.show()

# %%
labels = ['Categoria A','Categoria B','Categoria C']
values = [50,70,90]

plt.barh(labels,values)
plt.show()

# %%
x = [1,2,3,4,5]

y1 = [1,4,9,16,25]

y2 = [25,16,9,4,1]

plt.plot(x,y1)
plt.plot(x,y2)
plt.show()
